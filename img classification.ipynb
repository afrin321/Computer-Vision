# %%
pwd
# Out:
# 'E:\\Desktop\\semester 12\\CVAPR\\CIFAR -10'

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
from tqdm import tqdm
import pickle

# %%
DATASET = 'train'

# %%
img = cv2.imread('train/1.png', cv2.IMREAD_GRAYSCALE)
print(img.shape)
print(img)

plt.imshow(img, cmap='gray')
plt.xticks([])
plt.yticks([])
plt.show()
# Out:
# (32, 32)
# [[ 61  44  48 ... 137 130 128]
#  [ 18   0  10 ...  94  89  94]
#  [ 23   8  31 ...  90  90  80]
#  ...
#  [172 153 156 ... 133  35  38]
#  [146 128 143 ... 152  69  59]
#  [150 136 146 ... 188 123  98]]

# %%
path = DATASET
c=1
    #print(os.listdir(path))
for img in tqdm(os.listdir(path)):
    
    try:
        img_arr = cv2.imread(os.path.join(path, img), cv2.IMREAD_GRAYSCALE)
        img_resized = cv2.resize(img_arr, (IMG_SIZE, IMG_SIZE))
        train_data.append([img_resized], c)#train_label[c][1]
        c += 1
    except Exception as e:
        c += 1
        pass
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 50000/50000 [14:16<00:00, 58.35it/s]

# %%
train_data[0]
# Out:
# [array([[ 61,  61,  56, ..., 128, 128, 128],
#         [ 61,  61,  56, ..., 129, 128, 128],
#         [ 48,  48,  43, ..., 118, 118, 118],
#         ...,
#         [149, 149, 144, ...,  92,  86,  86],
#         [150, 150, 146, ..., 105,  98,  98],
#         [150, 150, 146, ..., 105,  98,  98]], dtype=uint8)]

# %%
for i in range(50):
    plt.subplot(5,10, i+1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(train_data[i][0], cmap=plt.cm.gray)
    #plt.xlabel(CATEGORIES[train_data[i][1]])
    
plt.show()

# %%
plt.xticks([])
plt.yticks([])
plt.imshow(train_data[49999][0], cmap=plt.cm.gray)
plt.show()

# %%
train_data[0:2]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c6fac03d0200> in <module>
# ----> 1 train_data[0:2]
#
# NameError: name 'train_data' is not defined

# %%
train_label = []
import csv
with open('trainLabels.csv', 'r') as file:
    reader = csv.reader(file, delimiter = ',')
    
    for row in reader:
        data = list(row)
        train_label.append(data)

# %%
print(train_label[0:5])
# Out:
# [['id', 'label'], ['1', 'frog'], ['2', 'truck'], ['3', 'truck'], ['4', 'deer']]

# %%
print(train_label[1])
print(train_label[1][1])

print(train_label[2])
print(train_label[2][1])
# Out:
# ['1', 'frog']
# frog
# ['2', 'truck']
# truck

# %%
pwd
# Out:
# 'E:\\Desktop\\semester 12\\CVAPR\\CIFAR -10'

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
from tqdm import tqdm
import pickle

# %%
DATASET = 'train'

# %%
path = DATASET
train_data = []
IMG_SIZE = 120
c=1
    #print(os.listdir(path))
for img in tqdm(os.listdir(path)):
    
    try:
        img_arr = cv2.imread(os.path.join(path, img), cv2.IMREAD_GRAYSCALE)
        img_resized = cv2.resize(img_arr, (IMG_SIZE, IMG_SIZE))
        train_data.append([img_resized, train_label[c][1]])#train_label[c][1]
        c += 1
    except Exception as e:
        c += 1
        pass
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████| 50000/50000 [00:54<00:00, 920.27it/s]

# %%
len(train_data)
# Out:
# 50000

# %%
train_data[0]
# Out:
# [array([[ 61,  61,  58, ..., 128, 128, 128],
#         [ 61,  61,  58, ..., 128, 128, 128],
#         [ 54,  54,  51, ..., 122, 122, 122],
#         ...,
#         [149, 149, 147, ...,  95,  91,  91],
#         [150, 150, 148, ..., 102,  98,  98],
#         [150, 150, 148, ..., 102,  98,  98]], dtype=uint8),
#  'frog']

# %%
train_data[0][0]
# Out:
# array([[ 61,  61,  58, ..., 128, 128, 128],
#        [ 61,  61,  58, ..., 128, 128, 128],
#        [ 54,  54,  51, ..., 122, 122, 122],
#        ...,
#        [149, 149, 147, ...,  95,  91,  91],
#        [150, 150, 148, ..., 102,  98,  98],
#        [150, 150, 148, ..., 102,  98,  98]], dtype=uint8)

# %%
for i in range(50):
    plt.subplot(5,10, i+1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(train_data[i][0], cmap=plt.cm.gray)
    plt.xlabel(train_label[i+1][1])
    
plt.show()

# %%
for i in range(50):
    plt.xticks([])
    plt.yticks([])
    plt.imshow(train_data[i][0], cmap=plt.cm.gray)
    plt.show()
